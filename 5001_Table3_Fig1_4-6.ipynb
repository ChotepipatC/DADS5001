# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from matplotlib import colors
from matplotlib import font_manager
from matplotlib.pyplot import figure
from matplotlib.patches import Patch
from matplotlib.colors import ListedColormap
from IPython.display import display

import matplotlib.transforms as transforms
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Add Thai front to plt
font_path = '/content/drive/MyDrive/Master_Degree/5001/Sarabun-ExtraBold.ttf'
font_manager.fontManager.addfont(font_path)
plt.rcParams['font.family'] = 'Sarabun'

# %% [markdown]
# ##Import & Prepare Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Master_Degree/5001/combined_v2.csv')

df = df[~df['prov'].isin(['กรมแพทย์ทหารเรือ', 'กรมแพทย์ทหารอากาศ'])]

df['prov'] = df['prov'].replace({'กรุงเทพฯ': 'กรุงเทพมหานคร'})
#display(df.head(3))

pdxG = pd.read_csv('/content/drive/MyDrive/Master_Degree/5001/pdx_master_with_draft_columns.csv')
#display(pdxG.head(3))

pop = pd.read_csv('/content/drive/MyDrive/Master_Degree/5001/DADS5001/n_pop_total.csv')
pop = pop.rename(columns={'yyyymm': 'month_no','province': 'prov'})
#display(pop.head(3))

re = pd.read_csv('/content/drive/MyDrive/Master_Degree/5001/DADS5001/province_region4.csv')
re = re.rename(columns={'ADM1_TH': 'prov'})
#display(re.head(3))


dfg = pd.merge(pdxG,df,  on='pdx', how='outer')
#display(df6.head(3))

dfgr = pd.merge(dfg, re, on='prov',how='outer')
#display(df8.head(3))

rpop = pd.merge(pop, re, on='prov')
#display(apop.head(3))

# %% [markdown]
# #OverAll

# %%
# Data
labels = ["สิทธิประกันสังคม/สิทธิประกันตนคนพิการฯ", "สิทธิข้าราชการ/รัฐวิสาหกิจ/สวัสดิการพนักงานส่วนท้องถิ่น","สิทธิประกันสุขภาพแห่งชาติ","สิทธิอื่นๆ"]
values = [ 12732348,6139334,46888435,1355804]


# Calculate percentages
perc = [(v / sum(values)) * 100 for v in values]

# Colors
colors = ['#3E5F44', '#5E936C', '#3498db', '#E8FFD7']

# Plot
fig, ax = plt.subplots(figsize=(15, 10))

# Determine which slice is the largest
explode = [0] * len(values)
largest_slice_index = values.index(max(values))
explode[largest_slice_index] = 0.1  # Make the largest slice "pop out"

# Function to format autopct with value in millions
def autopct_format(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return f'{val/1000000:.1f}M ({pct:.0f}%)'
    return my_autopct

wedges, texts, autotexts = ax.pie(values, colors=colors, wedgeprops=None, startangle=-40, autopct=autopct_format(values), explode=explode)

# Add data labels
for text, autotext in zip(texts, autotexts):
    text.set_color('grey')
    autotext.set_color('black')
    autotext.set_fontsize(15)


# Title + legend with only labels
plt.legend(
    wedges, labels,
    title="Healthcare service",
    loc="upper center",
    fontsize=14,
    bbox_to_anchor=(0.5, -0.1),
    ncol=len(labels)  # horizontal legend
)

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Overall N_Pop & N_Sevice

# %%
#Year by Year
fig, ax = plt.subplots(figsize=(20, 6))

mn=['Oct','Nov','Dec','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep']
yn=[2022,2023]
ln=0

for i in range(2022,2024):
  st = i*100+10
  en = (i+1)*100+9

  year=df.loc[ (df['month_no'] >= st)&(df['month_no'] <= en) , ['prov','gender','n_service','n_pop','pdx','month_no'] ].groupby('month_no')
  yf1=year[['n_service','n_pop']].agg('sum')
  yf1.reset_index(inplace=True)

  yx1=list(yf1.iloc[:,0])
  yy1=list(yf1.iloc[:,1])
  #yy2=list(yf1.iloc[:,2])

  # Get Y-axis limits for boundary check
  ymin, ymax = ax.get_ylim()
  offset = (ymax - ymin) * 0.02  # 2% offset

  # Add data labels within the frame
  for j, (x_pos, y1) in enumerate(zip(np.arange(len(yx1)), yy1)):
    # For y1 (blue)
    y1_pos = y1 + offset if y1 + offset < ymax else y1 - offset
    va1 = 'bottom' if y1 + offset < ymax else 'top'
    ax.text(x_pos, y1_pos, f"{y1:,.0f}", ha='center', va=va1, fontsize=9)


  ax.plot(np.arange(len(yx1)), yy1, marker='o', linestyle='-',label=yn[ln])
  ln=ln+1

  ax.set_xticks(np.arange(len(yx1)))
  ax.set_xticklabels(yx1)

  ax.set_xlabel('Month')
  ax.set_ylabel('n_service')
  ax.set_title('n_service/Month')

  plt.xticks(np.arange(len(mn)), mn, rotation=45)
  plt.grid(True)

plt.legend()
plt.show()

# %%
sam = df[['prov','gender','n_service','n_pop','pdx','month_no']].groupby('month_no')
gf1=sam[['n_service','n_pop']].agg('sum')
gf1.reset_index(inplace=True)

# %%
ax1=list(gf1.iloc[:,0])
ay1=list(gf1.iloc[:,1])
ay2=list(gf1.iloc[:,2])

fig, ax = plt.subplots(figsize=(20, 10))

# Plot the data using numerical indices for x-axis
ax.plot(np.arange(len(ax1)), ay1, marker='o', linestyle='-',label='n_service')
ax.plot(np.arange(len(ax1)), ay2, marker='o', linestyle='-',label='n_pop', color='orange')

# Set the x-tick locations to correspond to the indices
ax.set_xticks(np.arange(len(ax1)))
ax.set_xticklabels(ax1)

# Set the lower limit of the y-axis to 0
ax.set_ylim(bottom=0)

# Get Y-axis limits for boundary check
ymin, ymax = ax.get_ylim()
offset = (ymax - ymin) * 0.02  # 2% offset

# Add data labels within the frame
for i, (x_pos, y1, y2) in enumerate(zip(np.arange(len(ax1)), ay1, ay2)):
    # For y1 (blue)
    y1_pos = y1 + offset if y1 + offset < ymax else y1 - offset
    va1 = 'bottom' if y1 + offset < ymax else 'top'
    ax.text(x_pos, y1_pos, f"{y1:,.0f}", ha='center', va=va1, fontsize=9)

    # For y2 (orange)
    y2_pos = y2 + offset if y2 + offset < ymax else y2 - offset
    va2 = 'bottom' if y2 + offset < ymax else 'top'
    ax.text(x_pos, y2_pos, f"{y2:,.0f}", ha='center', va=va2, fontsize=9)

# Add labels and title
ax.set_xlabel('Month')
ax.set_ylabel('n_pop & n_service')
#ax.set_title('n_count/Month & n_service/Month')

# Display the plot
plt.xticks(np.arange(len(ax1)), ax1, rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
#By Province By Disease

pd_c = 'R00'
prov_c = 'สระบุรี'

sub=df.loc[ (df['pdx'] == pd_c) & (df['prov'] == prov_c) , ['prov','gender','n_service','n_pop','pdx','month_no'] ].groupby('month_no')
#sub.head(3)

gf2=sub[['n_service','n_pop']].agg('sum')
gf2.reset_index(inplace=True)
#gf2

bx1=list(gf2.iloc[:,0])
by1=list(gf2.iloc[:,1])
by2=list(gf2.iloc[:,2])

fig, ax = plt.subplots(figsize=(25, 6))

# Plot the data using numerical indices for x-axis
ax.plot(np.arange(len(bx1)), by1, marker='o', linestyle='-',label='n_service')
ax.plot(np.arange(len(bx1)), by2, marker='o', linestyle='-',label='n_pop', color='orange')

# Set the x-tick locations to correspond to the indices
ax.set_xticks(np.arange(len(bx1)))
ax.set_xticklabels(bx1)

# Get Y-axis limits for boundary check
ymin, ymax = ax.get_ylim()
offset = (ymax - ymin) * 0.02  # 2% offset

# Add data labels within the frame
for i, (x_pos, y1, y2) in enumerate(zip(np.arange(len(bx1)), by1, by2)):
    # For y1 (blue)
    y1_pos = y1 + offset if y1 + offset < ymax else y1 - offset
    va1 = 'bottom' if y1 + offset < ymax else 'top'
    ax.text(x_pos, y1_pos, f"{y1:,.0f}", ha='center', va=va1, fontsize=9)

    # For y2 (orange)
    y2_pos = y2 + offset if y2 + offset < ymax else y2 - offset
    va2 = 'bottom' if y2 + offset < ymax else 'top'
    ax.text(x_pos, y2_pos, f"{y2:,.0f}", ha='center', va=va2, fontsize=9)

# Set the lower limit of the y-axis to 0
ax.set_ylim(bottom=0)


# Add labels and title
ax.set_xlabel('Month')
ax.set_ylabel('n_pop')
#ax.set_title('n_count/Month')
plt.legend()

# Display the plot
plt.xticks(np.arange(len(bx1)), bx1, rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# #Region Overall

# %%
# Cal case by Region
case_by_re_m = dfgr[['prov','gender','n_service','n_pop','pdx','month_no','REGION4']].groupby(['REGION4','month_no'])
case_by_re_m = case_by_re_m[['n_pop','n_service']].agg('sum')

case_by_re_m.reset_index(inplace=True)

case_by_re_m_avg = case_by_re_m[['month_no','n_service','n_pop','REGION4']].groupby('REGION4')
case_by_re_m_avg = case_by_re_m_avg[['n_pop','n_service']].agg('mean')

case_by_re_m_avg.reset_index(inplace=True)

#display(df4.head(5))

# %%
#Select Pre Post
post = dfgr.loc[ dfgr['month_no'] == 202409 , ['prov','gender','n_service','n_pop','pdx','month_no','REGION4'] ].groupby('REGION4')
post = post[['n_service']].agg('sum')
post.reset_index(inplace=True)
post = post.rename(columns={'n_service': 'n_service_post'})

pre=dfgr.loc[ dfgr['month_no'] == 202210 , ['prov','gender','n_service','n_pop','pdx','month_no','REGION4'] ].groupby('REGION4')
pre = pre[['n_service']].agg('sum')
pre.reset_index(inplace=True)
pre = pre.rename(columns={'n_service': 'n_service_pre'})

#Cal case Growth
growth_case_r = pd.merge(post, pre, on='REGION4')
growth_case_r['%growth'] = (growth_case_r['n_service_post']/growth_case_r['n_service_pre'])-1
growth_case_r = growth_case_r.drop(columns=['n_service_post','n_service_pre'])

#display(growth_case_r.head(5))

# %%
# Cal pop by Region
pop_by_r_m = rpop[['prov','month_no','male','female','total_pop','REGION4']].groupby(['REGION4','month_no'])
pop_by_r_m = pop_by_r_m[['total_pop']].agg('sum')


pop_by_r_m.reset_index(inplace=True)

pop_by_r_m_avg = pop_by_r_m[['month_no','total_pop','REGION4']].groupby('REGION4')
pop_by_r_m_avg = pop_by_r_m_avg[['total_pop']].agg('mean')

pop_by_r_m_avg.reset_index(inplace=True)

#display(pop_by_r_m_avg.head(5))

#Cal Hospital admit rate per population Growth by region
tb1 = pd.merge(pop_by_r_m_avg,case_by_re_m_avg, on='REGION4')
tb1['n_Patients/Pop'] = (tb1['n_pop']/tb1['total_pop'])

# %%
# Combine calculated value
tb1 = pd.merge(tb1, growth_case_r, on='REGION4')
tb1 = tb1.drop(columns=['n_pop'])


#Visualize
tb1 = tb1.rename(columns={'total_pop': 'AVG Popoulation','n_service': 'AVG n_service'})

#display(g1.head(5))

tb1.style \
    .format({
        'AVG Popoulation': '{:,.2f}'.format,          # comma-separated integers
        'AVG n_service': '{:,.2f}'.format,          # comma-separated integers
        'n_Patients/Pop': '{:.2%}'.format,   # float with 2 decimals
        '%growth': '{:.2%}'.format                # percentage
    })\
    .bar(subset=['AVG Popoulation'], color='#2F486D') \
    .bar(subset=['AVG n_service'], color='#2F486D') \
    .background_gradient(subset=['n_Patients/Pop'], cmap='Reds')\
    .background_gradient(subset=['%growth'], cmap='Reds')
# Out:
# <style type="text/css">
# #T_908e6_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 82.8%, transparent 82.8%);
# }
# #T_908e6_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 54.7%, transparent 54.7%);
# }
# #T_908e6_row0_col3, #T_908e6_row1_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_908e6_row0_col4 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_908e6_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 23.9%, transparent 23.9%);
# }
# #T_908e6_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 18.1%, transparent 18.1%);
# }
# #T_908e6_row1_col3, #T_908e6_row3_col4 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_908e6_row2_col1, #T_908e6_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 100.0%, transparent 100.0%);
# }
# #T_908e6_row2_col3, #T_908e6_row4_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_908e6_row2_col4 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_908e6_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 48.8%, transparent 48.8%);
# }
# #T_908e6_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 45.8%, transparent 45.8%);
# }
# #T_908e6_row3_col3 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_908e6_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 48.5%, transparent 48.5%);
# }
# #T_908e6_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #2F486D 44.0%, transparent 44.0%);
# }
# #T_908e6_row4_col3 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_908e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_908e6_level0_col0" class="col_heading level0 col0" >REGION4</th>
#       <th id="T_908e6_level0_col1" class="col_heading level0 col1" >AVG Popoulation</th>
#       <th id="T_908e6_level0_col2" class="col_heading level0 col2" >AVG n_service</th>
#       <th id="T_908e6_level0_col3" class="col_heading level0 col3" >n_Patients/Pop</th>
#       <th id="T_908e6_level0_col4" class="col_heading level0 col4" >%growth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_908e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_908e6_row0_col0" class="data row0 col0" >ภาคกลาง</td>
#       <td id="T_908e6_row0_col1" class="data row0 col1" >17,982,018.12</td>
#       <td id="T_908e6_row0_col2" class="data row0 col2" >108,521.17</td>
#       <td id="T_908e6_row0_col3" class="data row0 col3" >0.58%</td>
#       <td id="T_908e6_row0_col4" class="data row0 col4" >19.15%</td>
#     </tr>
#     <tr>
#       <th id="T_908e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_908e6_row1_col0" class="data row1 col0" >ภาคตะวันออก</td>
#       <td id="T_908e6_row1_col1" class="data row1 col1" >5,196,127.08</td>
#       <td id="T_908e6_row1_col2" class="data row1 col2" >35,859.46</td>
#       <td id="T_908e6_row1_col3" class="data row1 col3" >0.67%</td>
#       <td id="T_908e6_row1_col4" class="data row1 col4" >18.28%</td>
#     </tr>
#     <tr>
#       <th id="T_908e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_908e6_row2_col0" class="data row2 col0" >ภาคตะวันออกเฉียงเหนือ</td>
#       <td id="T_908e6_row2_col1" class="data row2 col1" >21,722,646.67</td>
#       <td id="T_908e6_row2_col2" class="data row2 col2" >198,542.33</td>
#       <td id="T_908e6_row2_col3" class="data row2 col3" >0.88%</td>
#       <td id="T_908e6_row2_col4" class="data row2 col4" >22.79%</td>
#     </tr>
#     <tr>
#       <th id="T_908e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_908e6_row3_col0" class="data row3 col0" >ภาคเหนือ</td>
#       <td id="T_908e6_row3_col1" class="data row3 col1" >10,599,720.50</td>
#       <td id="T_908e6_row3_col2" class="data row3 col2" >90,928.08</td>
#       <td id="T_908e6_row3_col3" class="data row3 col3" >0.83%</td>
#       <td id="T_908e6_row3_col4" class="data row3 col4" >20.94%</td>
#     </tr>
#     <tr>
#       <th id="T_908e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_908e6_row4_col0" class="data row4 col0" >ภาคใต้</td>
#       <td id="T_908e6_row4_col1" class="data row4 col1" >10,542,809.92</td>
#       <td id="T_908e6_row4_col2" class="data row4 col2" >87,363.08</td>
#       <td id="T_908e6_row4_col3" class="data row4 col3" >0.81%</td>
#       <td id="T_908e6_row4_col4" class="data row4 col4" >27.80%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #Disease Growth rate

# %%
# Cal How much each disease group admit
service_by_dise = dfgr[['n_service','n_pop','month_no','ICD10_Chapter']].groupby(['ICD10_Chapter'])
service_by_dise = service_by_dise[['n_service']].agg('sum')

service_by_dise.reset_index(inplace=True)

service_by_dise = service_by_dise.sort_values(by='n_service', ascending=False)
#service_by_dise.head(3)

# %%
#Select Pre Post
post1 = dfgr.loc[ dfgr['month_no'] == 202409 , ['prov','ICD10_Chapter','n_service','n_pop','pdx','month_no'] ].groupby(['ICD10_Chapter'])
post1 = post1[['n_service']].agg('sum')
post1.reset_index(inplace=True)
post1 = post1.rename(columns={'n_service': 'n_service_post1'})


pre1 = dfgr.loc[ dfgr['month_no'] == 202210 , ['prov','ICD10_Chapter','n_service','n_pop','pdx','month_no'] ].groupby(['ICD10_Chapter'])
pre1 = pre1[['n_service']].agg('sum')
pre1.reset_index(inplace=True)
pre1 = pre1.rename(columns={'n_service': 'n_service_pre1'})

#Cal n_service Growth for each disease group
gr1 = pd.merge(post1, pre1, on='ICD10_Chapter',how='inner')
gr1['%growth_ser'] = (gr1['n_service_post1']/gr1['n_service_pre1'])-1
gr1 = gr1.drop(columns=['n_service_post1','n_service_pre1'])

gr1= pd.merge(gr1,service_by_dise,  on='ICD10_Chapter', how='outer')

#Cal %Service Participaiton of each disease group
total_service = gr1['n_service'].sum()
gr1['%participation_n_service'] = gr1['n_service'] / total_service

# %%
#Visualize
gr1 = gr1[['ICD10_Chapter','n_service','%participation_n_service','%growth_ser']]

gr1 = gr1.sort_values(by='%participation_n_service', ascending=False)
#display(gr1.head(5))

gr1.style \
    .format({
        'n_service': '{:,.2f}'.format,
        '%participation_n_service': '{:,.2%}'.format,
        '%growth_ser': '{:.2%}'.format
    })\
    .bar(subset=['n_service'], color='#2F486D') \
    .bar(subset=['%participation_n_service'], color='#2F486D') \
    .bar(subset=['%growth_ser'], color='#2F486D')

# %% [markdown]
# #%Propotion of disease group for each region

# %%
# Cal case by Region
propo_group = dfgr[['n_service','month_no','REGION4','ICD10_Focus']].groupby(['REGION4','month_no','ICD10_Focus'])
propo_group = propo_group[['n_service']].agg('sum')

propo_group.reset_index(inplace=True)

propo_group = propo_group[['n_service','REGION4','ICD10_Focus']].groupby(['REGION4','ICD10_Focus'])
propo_group = propo_group[['n_service']].agg('mean')

propo_group.reset_index(inplace=True)

# Calculate overall country proportions
overall_country = dfgr[['n_service','month_no','ICD10_Focus']].groupby(['month_no','ICD10_Focus'])
overall_country = overall_country[['n_service']].agg('sum')
overall_country.reset_index(inplace=True)
overall_country = overall_country[['n_service','ICD10_Focus']].groupby(['ICD10_Focus'])
overall_country = overall_country[['n_service']].agg('mean')
overall_country.reset_index(inplace=True)
overall_country['REGION4'] = 'Overall Country'

# Concatenate regional and overall data
combined_proportions = pd.concat([propo_group, overall_country])

# Pivot the dataframe to have REGION4 as index and ICD10_Chapter as columns
pivot_df = combined_proportions.pivot_table(index='REGION4', columns='ICD10_Focus', values='n_service', aggfunc='sum', fill_value=0)

# Normalize the data to make it 100%
pivot_df_normalized = pivot_df.div(pivot_df.sum(axis=1), axis=0) * 100

# Plot the 100% stacked bar chart (horizontal)
ax = pivot_df_normalized.plot(kind='barh', stacked=True, figsize=(10,6), colormap='tab20')

# Adding labels and title
ax.set_xlabel('Percentage')
#ax.set_title('100% Stacked Bar Chart of Services by ICD10 Focus and Region')
ax.legend(title='ICD10 Focus', loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=3) # Adjusted bbox_to_anchor

# Add percentage labels inside the bars
for p in ax.patches:
    width = p.get_width()  # Get the width of each segment (which represents the percentage)
    if width > 0:  # Avoid division by zero
        ax.text(p.get_x() + width / 2, p.get_y() + p.get_height() / 2, f'{width:.1f}%',
                ha='center', va='center', color='black', fontsize=10)

plt.tight_layout()
plt.subplots_adjust(bottom=0.25)  # Adjust the bottom margin to make space for the legend
plt.show()

# %% [markdown]
# #%Propotion of Communicable_vs_NCD disease for each region

# %%
# Cal case by Region
propo_group = dfgr[['n_service','month_no','REGION4','Communicable_vs_NCD']].groupby(['REGION4','month_no','Communicable_vs_NCD'])
propo_group = propo_group[['n_service']].agg('sum')

propo_group.reset_index(inplace=True)

propo_group = propo_group[['n_service','REGION4','Communicable_vs_NCD']].groupby(['REGION4','Communicable_vs_NCD'])
propo_group = propo_group[['n_service']].agg('mean')

propo_group.reset_index(inplace=True)

# Calculate overall country proportions
overall_country = dfgr[['n_service','month_no','Communicable_vs_NCD']].groupby(['month_no','Communicable_vs_NCD'])
overall_country = overall_country[['n_service']].agg('sum')
overall_country.reset_index(inplace=True)
overall_country = overall_country[['n_service','Communicable_vs_NCD']].groupby(['Communicable_vs_NCD'])
overall_country = overall_country[['n_service']].agg('mean')
overall_country.reset_index(inplace=True)
overall_country['REGION4'] = 'Overall Country'

# Concatenate regional and overall data
combined_proportions = pd.concat([propo_group, overall_country])

# Pivot the dataframe to have REGION4 as index and ICD10_Chapter as columns
pivot_df = combined_proportions.pivot_table(index='REGION4', columns='Communicable_vs_NCD', values='n_service', aggfunc='sum', fill_value=0)

# Normalize the data to make it 100%
pivot_df_normalized = pivot_df.div(pivot_df.sum(axis=1), axis=0) * 100

# Define a colormap and map values to colors
cmap = plt.get_cmap('tab20')
colors = cmap(np.linspace(0, 1, len(pivot_df_normalized.columns)))
color_map = {col: colors[i] for i, col in enumerate(pivot_df_normalized.columns)}

# Plot the 100% stacked bar chart (horizontal) using the defined color map
ax = pivot_df_normalized.plot(kind='barh', stacked=True, figsize=(10,6), color=[color_map[col] for col in pivot_df_normalized.columns])

# Adding labels and title
ax.set_xlabel('Percentage')
#ax.set_title('100% Stacked Bar Chart of Services by ICD10 Focus and Region')
ax.legend(title='Communicable', loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=3) # Adjusted bbox_to_anchor

# Add percentage labels inside the bars
for p in ax.patches:
    width = p.get_width()  # Get the width of each segment (which represents the percentage)
    if width > 0:  # Avoid division by zero
        ax.text(p.get_x() + width / 2, p.get_y() + p.get_height() / 2, f'{width:.1f}%',
                ha='center', va='center', color='black', fontsize=10)

plt.tight_layout()
plt.subplots_adjust(bottom=0.25)  # Adjust the bottom margin to make space for the legend
plt.show()

# %% [markdown]
# #%Propotion of disease group for each region

# %%
# Cal case by Region
propo_group = dfgr[['n_service','month_no','REGION4','Preventable']].groupby(['REGION4','month_no','Preventable'])
propo_group = propo_group[['n_service']].agg('sum')

propo_group.reset_index(inplace=True)

propo_group = propo_group[['n_service','REGION4','Preventable']].groupby(['REGION4','Preventable'])
propo_group = propo_group[['n_service']].agg('mean')

propo_group.reset_index(inplace=True)

# Calculate overall country proportions
overall_country = dfgr[['n_service','month_no','Preventable']].groupby(['month_no','Preventable'])
overall_country = overall_country[['n_service']].agg('sum')
overall_country.reset_index(inplace=True)
overall_country = overall_country[['n_service','Preventable']].groupby(['Preventable'])
overall_country = overall_country[['n_service']].agg('mean')
overall_country.reset_index(inplace=True)
overall_country['REGION4'] = 'Overall Country'

# Concatenate regional and overall data
combined_proportions = pd.concat([propo_group, overall_country])

# Pivot the dataframe to have REGION4 as index and ICD10_Chapter as columns
pivot_df = combined_proportions.pivot_table(index='REGION4', columns='Preventable', values='n_service', aggfunc='sum', fill_value=0)

# Normalize the data to make it 100%
pivot_df_normalized = pivot_df.div(pivot_df.sum(axis=1), axis=0) * 100

# Define a colormap and map values to colors
cmap = plt.get_cmap('tab20')
colors = cmap(np.linspace(0, 1, len(pivot_df_normalized.columns)))
color_map = {col: colors[i] for i, col in enumerate(pivot_df_normalized.columns)}

# Plot the 100% stacked bar chart (horizontal) using the defined color map
ax = pivot_df_normalized.plot(kind='barh', stacked=True, figsize=(10,6), color=[color_map[col] for col in pivot_df_normalized.columns])

# Adding labels and title
ax.set_xlabel('Percentage')
#ax.set_title('100% Stacked Bar Chart of Services by ICD10 Focus and Region')
ax.legend(title='Preventable', loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=3) # Adjusted bbox_to_anchor

# Add percentage labels inside the bars
for p in ax.patches:
    width = p.get_width()  # Get the width of each segment (which represents the percentage)
    if width > 0:  # Avoid division by zero
        ax.text(p.get_x() + width / 2, p.get_y() + p.get_height() / 2, f'{width:.1f}%',
                ha='left', va='center', color='black', fontsize=10)

plt.tight_layout()
plt.subplots_adjust(bottom=0.25)  # Adjust the bottom margin to make space for the legend
plt.show()

# %% [markdown]
# #Top 5 pdx of each Region

# %%
#Chat GPT
# --- Step 1: Get PDX metadata (unique) ---
pdx_detail_cols = ['pdx', 'Name', 'ICD10_Chapter', 'Communicable_vs_NCD', 'Preventable']
pdx_detail = dfgr[pdx_detail_cols].drop_duplicates(subset='pdx')

# --- Step 2: Collect top 5 pdx per region ---
regions = tb1.iloc[:, 0]  # region names
region_rankings = []
all_top5_pdx = set()

for region_name in regions:
    df_region = dfgr[dfgr['REGION4'] == region_name]

    df_mean = (
        df_region
        .groupby(['pdx', 'month_no'])['n_service']
        .sum()
        .groupby('pdx')
        .mean()
        .reset_index()
    )

    df_mean['Rank'] = df_mean['n_service'].rank(method='first', ascending=False).astype(int)
    df_top5 = df_mean.nsmallest(5, 'Rank')

    all_top5_pdx.update(df_top5['pdx'])

    for _, row in df_top5.iterrows():
        region_rankings.append({
            'pdx': row['pdx'],
            'Region': region_name,
            'Rank': row['Rank']
        })

# --- Step 3: Create wide table ---
df_ranks = pd.DataFrame(region_rankings)
pivot_ranks = df_ranks.pivot(index='pdx', columns='Region', values='Rank')

# --- Step 4: Calculate total n_service for each pdx across all regions ---
total_service_per_pdx = dfgr.groupby('pdx')['n_service'].sum().reset_index()
total_service_per_pdx = total_service_per_pdx.rename(columns={'n_service': 'Total_n_service'})

# --- Step 5: Merge with pdx details and total service ---
top5pdx_re = pivot_ranks.reset_index().merge(pdx_detail, on='pdx', how='left')
top5pdx_re = top5pdx_re.merge(total_service_per_pdx, on='pdx', how='left')
top5pdx_re = top5pdx_re.set_index('pdx').loc[sorted(all_top5_pdx)].reset_index()

# --- Step 6: Reorder columns (move region columns to the end) ---
cols = top5pdx_re.columns.tolist()
region_cols = cols[1:1+len(regions)]
other_cols = cols[0:1] + cols[1+len(regions):]
new_cols_order = other_cols + region_cols
top5pdx_re = top5pdx_re[new_cols_order]

# %%
top5pdx_re
# Out:
#    pdx                                               Name  \
# 0  A09  Other gastroenteritis and colitis of infectiou...
# 1  D56                                       Thalassaemia
# 2  E11                           Type 2 diabetes mellitus
# 3  H25                                    Senile cataract
# 4  I50                                      Heart failure
# 5  I63                                Cerebral infarction
# 6  J18                    Pneumonia, organism unspecified
# 7  J44        Other chronic obstructive pulmonary disease
# 8  N18                             Chronic kidney disease
# 9  O80                        Single spontaneous delivery
#
#                                        ICD10_Chapter Communicable_vs_NCD  \
# 0  A00-B99: Certain infectious and parasitic dise...        Communicable
# 1                   D50-D89: Blood and immune system    Non-Communicable
# 2         E00-E89: Endocrine, nutritional, metabolic    Non-Communicable
# 3                            H00-H59: Eye and adnexa    Non-Communicable
# 4                        I00-I99: Circulatory system    Non-Communicable
# 5                        I00-I99: Circulatory system    Non-Communicable
# 6                        J00-J99: Respiratory system    Non-Communicable
# 7                        J00-J99: Respiratory system    Non-Communicable
# 8                      N00-N99: Genitourinary system    Non-Communicable
# 9                     O00-O99: Pregnancy, childbirth    Non-Communicable
#
#                    Preventable  Total_n_service  ภาคกลาง  ภาคตะวันออก  \
# 0  Not-preventable/Unspecified           595029      2.0          1.0
# 1  Not-preventable/Unspecified           247997      NaN          NaN
# 2        Lifestyle-preventable           254872      NaN          NaN
# 3  Not-preventable/Unspecified           381254      1.0          3.0
# 4  Not-preventable/Unspecified           249496      4.0          5.0
# 5  Not-preventable/Unspecified           240087      5.0          4.0
# 6  Not-preventable/Unspecified           483870      3.0          2.0
# 7  Not-preventable/Unspecified           262244      NaN          NaN
# 8  Not-preventable/Unspecified           261119      NaN          NaN
# 9  Not-preventable/Unspecified           175552      NaN          NaN
#
#    ภาคตะวันออกเฉียงเหนือ  ภาคเหนือ  ภาคใต้
# 0                    1.0       1.0     1.0
# 1                    NaN       4.0     NaN
# 2                    4.0       NaN     NaN
# 3                    5.0       3.0     4.0
# 4                    NaN       NaN     NaN
# 5                    NaN       NaN     NaN
# 6                    2.0       2.0     2.0
# 7                    NaN       5.0     3.0
# 8                    3.0       NaN     NaN
# 9                    NaN       NaN     5.0

# %%
#Chat GPT

# --- Identify region columns (assume they are at the end) ---
region_cols_new_pos = top5pdx_re.columns[-len(regions):]

# --- Prepare data ---
top5pdx_re_no0 = top5pdx_re.copy()

# Replace 0 with pd.NA and convert to nullable integer type
for col in region_cols_new_pos:
    top5pdx_re_no0[col] = top5pdx_re_no0[col].replace(0, pd.NA).astype("Int64")

# --- Define custom colormap: dark red → white ---
cmap = colors.LinearSegmentedColormap.from_list("color", ["#a83246", "white"])

# --- Apply styling ---
styled = (
    top5pdx_re_no0.style
    # Heatmap only for region columns
    .background_gradient(cmap=cmap, subset=region_cols_new_pos, axis=None)
    # Format only Total_n_service with thousand separators
    .format({'Total_n_service': '{:,.0f}'})
    # Keep NaN (and former zeros) white
    .highlight_null(props="background-color: white;")
)

styled
# Out:
# <style type="text/css">
# #T_a6b73_row0_col6, #T_a6b73_row6_col7, #T_a6b73_row6_col8, #T_a6b73_row6_col9, #T_a6b73_row6_col10 {
#   background-color: #be6574;
#   color: #f1f1f1;
# }
# #T_a6b73_row0_col7, #T_a6b73_row0_col8, #T_a6b73_row0_col9, #T_a6b73_row0_col10, #T_a6b73_row3_col6 {
#   background-color: #a83246;
#   color: #f1f1f1;
# }
# #T_a6b73_row1_col6, #T_a6b73_row1_col7, #T_a6b73_row1_col8, #T_a6b73_row1_col10, #T_a6b73_row2_col6, #T_a6b73_row2_col7, #T_a6b73_row2_col9, #T_a6b73_row2_col10, #T_a6b73_row4_col8, #T_a6b73_row4_col9, #T_a6b73_row4_col10, #T_a6b73_row5_col8, #T_a6b73_row5_col9, #T_a6b73_row5_col10, #T_a6b73_row7_col6, #T_a6b73_row7_col7, #T_a6b73_row7_col8, #T_a6b73_row8_col6, #T_a6b73_row8_col7, #T_a6b73_row8_col9, #T_a6b73_row8_col10, #T_a6b73_row9_col6, #T_a6b73_row9_col7, #T_a6b73_row9_col8, #T_a6b73_row9_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_a6b73_row1_col9, #T_a6b73_row2_col8, #T_a6b73_row3_col10, #T_a6b73_row4_col6, #T_a6b73_row5_col7 {
#   background-color: #eaccd1;
#   color: #000000;
# }
# #T_a6b73_row3_col7, #T_a6b73_row3_col9, #T_a6b73_row6_col6, #T_a6b73_row7_col10, #T_a6b73_row8_col8 {
#   background-color: #d499a3;
#   color: #f1f1f1;
# }
# #T_a6b73_row3_col8, #T_a6b73_row4_col7, #T_a6b73_row5_col6, #T_a6b73_row7_col9, #T_a6b73_row9_col10 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_a6b73" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6b73_level0_col0" class="col_heading level0 col0" >pdx</th>
#       <th id="T_a6b73_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a6b73_level0_col2" class="col_heading level0 col2" >ICD10_Chapter</th>
#       <th id="T_a6b73_level0_col3" class="col_heading level0 col3" >Communicable_vs_NCD</th>
#       <th id="T_a6b73_level0_col4" class="col_heading level0 col4" >Preventable</th>
#       <th id="T_a6b73_level0_col5" class="col_heading level0 col5" >Total_n_service</th>
#       <th id="T_a6b73_level0_col6" class="col_heading level0 col6" >ภาคกลาง</th>
#       <th id="T_a6b73_level0_col7" class="col_heading level0 col7" >ภาคตะวันออก</th>
#       <th id="T_a6b73_level0_col8" class="col_heading level0 col8" >ภาคตะวันออกเฉียงเหนือ</th>
#       <th id="T_a6b73_level0_col9" class="col_heading level0 col9" >ภาคเหนือ</th>
#       <th id="T_a6b73_level0_col10" class="col_heading level0 col10" >ภาคใต้</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6b73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6b73_row0_col0" class="data row0 col0" >A09</td>
#       <td id="T_a6b73_row0_col1" class="data row0 col1" >Other gastroenteritis and colitis of infectious and unspecified origin</td>
#       <td id="T_a6b73_row0_col2" class="data row0 col2" >A00-B99: Certain infectious and parasitic diseases</td>
#       <td id="T_a6b73_row0_col3" class="data row0 col3" >Communicable</td>
#       <td id="T_a6b73_row0_col4" class="data row0 col4" >Not-preventable/Unspecified</td>
#       <td id="T_a6b73_row0_col5" class="data row0 col5" >595,029</td>
#       <td id="T_a6b73_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_a6b73_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_a6b73_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_a6b73_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_a6b73_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a6b73_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6b73_row1_col0" class="data row1 col0" >D56</td>
#       <td id="T_a6b73_row1_col1" class="data row1 col1" >Thalassaemia</td>
#       <td id="T_a6b73_row1_col2" class="data row1 col2" >D50-D89: Blood and immune system</td>
#       <td id="T_a6b73_row1_col3" class="data row1 col3" >Non-Communicable</td>
#       <td id="T_a6b73_row1_col4" class="data row1 col4" >Not-preventable/Unspecified</td>
#       <td id="T_a6b73_row1_col5" class="data row1 col5" >247,997</td>
#       <td id="T_a6b73_row1_col6" class="data row1 col6" ><NA></td>
#       <td id="T_a6b73_row1_col7" class="data row1 col7" ><NA></td>
#       <td id="T_a6b73_row1_col8" class="data row1 col8" ><NA></td>
#       <td id="T_a6b73_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_a6b73_row1_col10" class="data row1 col10" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_a6b73_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6b73_row2_col0" class="data row2 col0" >E11</td>
#       <td id="T_a6b73_row2_col1" class="data row2 col1" >Type 2 diabetes mellitus</td>
#       <td id="T_a6b73_row2_col2" class="data row2 col2" >E00-E89: Endocrine, nutritional, metabolic</td>
#       <td id="T_a6b73_row2_col3" class="data row2 col3" >Non-Communicable</td>
#       <td id="T_a6b73_row2_col4" class="data row2 col4" >Lifestyle-preventable</td>
#       <td id="T_a6b73_row2_col5" class="data row2 col5" >254,872</td>
#       <td id="T_a6b73_row2_col6" class="data row2 col6" ><NA></td>
#       <td id="T_a6b73_row2_col7" class="data row2 col7" ><NA></td>
#       <td id="T_a6b73_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_a6b73_row2_col9" class="data row2 col9" ><NA></td>
#       <td id="T_a6b73_row2_col10" class="data row2 col10" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_a6b73_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6b73_row3_col0" class="data row3 col0" >H25</td>
#       <td id="T_a6b73_row3_col1" class="data row3 col1" >Senile cataract</td>
#       <td id="T_a6b73_row3_col2" class="data row3 col2" >H00-H59: Eye and adnexa</td>
#       <td id="T_a6b73_row3_col3" class="data row3 col3" >Non-Communicable</td>
#       <td id="T_a6b73_row3_col4" class="data row3 col4" >Not-preventable/Unspecified</td>
#       <td id="T_a6b73_row3_col5" class="data row3 col5" >381,254</td>
#       <td id="T_a6b73_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_a6b73_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_a6b73_row3_col8" class="data row3 col8" >5</td>
#       <td id="T_a6b73_row3_col9" class="data row3 col9" >3</td>
#       <td id="T_a6b73_row3_col10" class="data row3 col10" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a6b73_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6b73_row4_col0" class="data row4 col0" >I50</td>
#       <td id="T_a6b73_row4_col1" class="data row4 col1" >Heart failure</td>
#       <td id="T_a6b73_row4_col2" class="data row4 col2" >I00-I99: Circulatory system</td>
#       <td id="T_a6b73_row4_col3" class="data row4 col3" >Non-Communicable</td>
#       <td id="T_a6b73_row4_col4" class="data row4 col4" >Not-preventable/Unspecified</td>
#       <td id="T_a6b73_row4_col5" class="data row4 col5" >249,496</td>
#       <td id="T_a6b73_row4_col6" class="data row4 col6" >4</td>
#       <td id="T_a6b73_row4_col7" class="data row4 col7" >5</td>
#       <td id="T_a6b73_row4_col8" class="data row4 col8" ><NA></td>
#       <td id="T_a6b73_row4_col9" class="data row4 col9" ><NA></td>
#       <td id="T_a6b73_row4_col10" class="data row4 col10" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_a6b73_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6b73_row5_col0" class="data row5 col0" >I63</td>
#       <td id="T_a6b73_row5_col1" class="data row5 col1" >Cerebral infarction</td>
#       <td id="T_a6b73_row5_col2" class="data row5 col2" >I00-I99: Circulatory system</td>
#       <td id="T_a6b73_row5_col3" class="data row5 col3" >Non-Communicable</td>
#       <td id="T_a6b73_row5_col4" class="data row5 col4" >Not-preventable/Unspecified</td>
#       <td id="T_a6b73_row5_col5" class="data row5 col5" >240,087</td>
#       <td id="T_a6b73_row5_col6" class="data row5 col6" >5</td>
#       <td id="T_a6b73_row5_col7" class="data row5 col7" >4</td>
#       <td id="T_a6b73_row5_col8" class="data row5 col8" ><NA></td>
#       <td id="T_a6b73_row5_col9" class="data row5 col9" ><NA></td>
#       <td id="T_a6b73_row5_col10" class="data row5 col10" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_a6b73_level0_row6" class="row_heading level0 row6" >6</th>
#       <td i

# %%
# --- Step 1: Get PDX metadata (unique) ---
pdx_detail_cols = ['pdx', 'Name', 'Thai', 'ICD10_Chapter', 'Communicable_vs_NCD', 'Preventable']
pdx_detail = dfgr[pdx_detail_cols].drop_duplicates(subset='pdx')

# --- Step 2: Collect top 5 pdx per region ---
regions = tb1.iloc[:, 0]  # region names
region_rankings = []
all_top5_pdx = set()

for region_name in regions:
    df_region = dfgr[dfgr['REGION4'] == region_name]

    df_mean = (
        df_region
        .groupby(['pdx', 'month_no'])['n_service']
        .sum()
        .groupby('pdx')
        .mean()
        .reset_index()
    )

    df_mean['Rank'] = df_mean['n_service'].rank(method='first', ascending=False).astype(int)
    df_top5 = df_mean.nsmallest(5, 'Rank')

    all_top5_pdx.update(df_top5['pdx'])

    for _, row in df_top5.iterrows():
        region_rankings.append({
            'pdx': row['pdx'],
            'Region': region_name,
            'Rank': row['Rank']
        })

# --- Step 3: Create wide table ---
df_ranks = pd.DataFrame(region_rankings)
pivot_ranks = df_ranks.pivot(index='pdx', columns='Region', values='Rank')

# --- Step 4: Calculate total n_service for each pdx across all regions ---
total_service_per_pdx = dfgr.groupby('pdx')['n_service'].sum().reset_index()
total_service_per_pdx = total_service_per_pdx.rename(columns={'n_service': 'Total_n_service'})

# --- Step 5: Merge with pdx details and total service ---
top5pdx_re = pivot_ranks.reset_index().merge(pdx_detail, on='pdx', how='left')
top5pdx_re = top5pdx_re.merge(total_service_per_pdx, on='pdx', how='left')
top5pdx_re = top5pdx_re.set_index('pdx').loc[sorted(all_top5_pdx)].reset_index()
top5pdx_re = top5pdx_re.fillna(0)

top5pdx_re

# %%
#Stak bar
# All regions
regions = tb1.iloc[:, 0]

# Custom color palette (expand if needed)
custom_colors = ['#8a2e54', '#d53e4f', '#f46d43', '#6c55e9', '#fee08b',
                 '#e9ff79', '#55a04b', '#66c2a5', '#3288bd', '#5e4fa2']

# Track all pdx used in top 5 per region
used_pdx_set = set()

# First pass: Collect all top-5 pdx across all regions
for region_name in regions:
    filtered_df = dfgr[dfgr['REGION4'] == region_name]

    propo_group = (
        filtered_df
        .groupby(['REGION4', 'month_no', 'pdx'])['n_service']
        .sum()
        .reset_index()
    )

    propo_group = (
        propo_group
        .groupby(['REGION4', 'pdx'])['n_service']
        .mean()
        .reset_index()
    )

    top_5_pdx = (
        propo_group
        .groupby('pdx')['n_service']
        .sum()
        .sort_values(ascending=False)
        .head(5)
        .index
    )

    used_pdx_set.update(top_5_pdx)

#Only assign colors to used pdx
used_pdx_list = sorted(used_pdx_set)

# Ensure enough custom colors
if len(custom_colors) < len(used_pdx_list):
    repeat_times = (len(used_pdx_list) // len(custom_colors)) + 1
    custom_colors = (custom_colors * repeat_times)[:len(used_pdx_list)]

# Build pdx → color map
pdx_color_map = {pdx: custom_colors[i] for i, pdx in enumerate(used_pdx_list)}

# --- Plotting ---

n_regions = len(regions)
fig, axes = plt.subplots(nrows=n_regions, ncols=1, figsize=(10, 2 * n_regions), sharex=True)

# Ensure axes is iterable
if n_regions == 1:
    axes = [axes]

for ax, region_name in zip(axes, regions):
    filtered_df = dfgr[dfgr['REGION4'] == region_name]

    propo_group = (
        filtered_df
        .groupby(['REGION4', 'month_no', 'pdx'])['n_service']
        .sum()
        .reset_index()
    )

    propo_group = (
        propo_group
        .groupby(['REGION4', 'pdx'])['n_service']
        .mean()
        .reset_index()
    )

    top_5_pdx = (
        propo_group
        .groupby('pdx')['n_service']
        .sum()
        .sort_values(ascending=False)
        .head(5)
        .index
    )

    filtered_top_5 = propo_group[propo_group['pdx'].isin(top_5_pdx)]

    pivot_df = filtered_top_5.pivot_table(
        index='REGION4',
        columns='pdx',
        values='n_service',
        aggfunc='sum',
        fill_value=0
    )

    pivot_df_percentage = pivot_df.div(pivot_df.sum(axis=1), axis=0) * 100

    # Sort columns (pdx) by descending contribution
    sorted_pdx = pivot_df_percentage.iloc[0].sort_values(ascending=False).index
    pivot_df_percentage = pivot_df_percentage[sorted_pdx]

    plot_colors = [pdx_color_map[pdx] for pdx in pivot_df_percentage.columns]

    pivot_df_percentage.plot(
        kind='barh',
        stacked=True,
        ax=ax,
        color=plot_colors,
        edgecolor='black',
        legend=False
    )

    #ax.set_title(f'{region_name}', loc='left', fontsize=11)
    ax.set_ylabel('')
    ax.set_xlabel('Percentage')

    for p in ax.patches:
        width = p.get_width()
        if width > 0:
            ax.text(
                p.get_x() + width / 2,
                p.get_y() + p.get_height() / 2,
                f'{width:.1f}%',
                ha='center',
                va='center',
                fontsize=8,
                color='black'
            )

# Manual legend based on actual used pdx
legend_elements = [
    Patch(facecolor=pdx_color_map[pdx], edgecolor='black', label=pdx)
    for pdx in used_pdx_list
]

fig.legend(
    handles=legend_elements,
    title='pdx Code',
    loc='upper right',
    bbox_to_anchor=(1.12, 1),
    ncol=1
)

plt.tight_layout(rect=[0, 0, 0.9, 1])
#plt.suptitle('Top 5 disease Focus by Region (100% Stacked Bars)', fontsize=14, y=1.02)
plt.show()

# %% [markdown]
# #Population compare to IPUC Service

# %%
# Data (assuming tb1 is already defined with the appropriate data)
regions = tb1['REGION4']
pop = tb1['AVG Popoulation']
service = tb1['AVG n_service']

# Sort tb1 by 'AVG n_service' in descending order
tb1_sorted = tb1.sort_values(by='AVG n_service', ascending=True)

regions_sorted = tb1_sorted['REGION4']
pop_sorted = tb1_sorted['AVG Popoulation']
service_sorted = tb1_sorted['AVG n_service']

y = np.arange(len(regions_sorted))

# Function to format the x-axis labels
def thousand_separator(x, pos):
    return f'{int(x):,}'  # Adds comma as a thousand separator

# Create two subplots side by side, sharing y-axis
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(14, 6), gridspec_kw={'wspace': 0.35})  # Increased wspace

# Left plot (Population)
bars1 = ax1.barh(y, pop_sorted, color="#2F486D")
ax1.xaxis.set_major_formatter(FuncFormatter(thousand_separator))
ax1.set(title="Population")
ax1.invert_xaxis()   # mirror effect
ax1.set_yticks(y)    # keep the y-axis ticks for the region names

# Add data labels for Population
for bar in bars1:
    w = bar.get_width()
    ax1.text(w - (0.02 * max(pop_sorted)), bar.get_y() + bar.get_height()/2,
             f"{int(w):,}", ha="left", va="center", color="white", fontsize=9)

# Right plot (Service)
bars2 = ax2.barh(y, service_sorted, color="#D94F4F")
ax2.xaxis.set_major_formatter(FuncFormatter(thousand_separator))
ax2.set(title="Service")
ax2.set_yticks([])   # hide y-axis labels on the right plot

# Add data labels for Service
for bar in bars2:
    w = bar.get_width()
    ax2.text(w - (0.02 * max(service_sorted)), bar.get_y() + bar.get_height()/2,
             f"{int(w):,}", ha="right", va="center", color="white", fontsize=9)

# Add region names exactly on the y-axis (move significantly to the right)
for i, region in enumerate(regions_sorted):
    # Move the region names further from the y-axis by increasing the x-coordinate
    ax2.text(ax2.get_xlim()[0] -0.17 * (ax2.get_xlim()[1] - ax2.get_xlim()[0]), bars1[i].get_y() + bars1[i].get_height()/2,
             region, ha="center", va="center", fontsize=10)


plt.tight_layout()
plt.show()
